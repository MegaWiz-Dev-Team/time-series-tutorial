# %% [markdown]
# # Level 3: Predictive ML Pipeline\nThis notebook demonstrates the training pipeline for the epoch-based OSA classifier.

# %%
# !python src/train.py
# Out:
# Processing ../../data/raw\patient_001...
# Processing ../../data/raw\patient_002...
# Training RandomForestClassifier on 1642 epochs...
# \nTraining Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.97       420
#          1.0       0.99      0.99      0.99      1222
#
#     accuracy                           0.98      1642
#    macro avg       0.97      0.98      0.98      1642
# weighted avg       0.98      0.98      0.98      1642
#
# Model saved to ../models/osa_classifier.pkl
# C:\Users\ropcj\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\numpy\lib\_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ropcj\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\numpy\lib\_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# ...
